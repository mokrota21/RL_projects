# %% [markdown]
# # Full vision update_step = 1

# %%
import json
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Function to load JSON file
def load_json(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

# Load JSON files
count = 0
files = []
data = []
filenames = []
while True:
    file = '../vision_' + str(count) + '.json'
    try:
        data.append(load_json(file_path=file))
        filenames.append(file)
        print(file)
    except:
        break
    count += 1

for filepath in files:
    data.append(load_json(file_path=filepath))

# Plot comparison of a specific field using Plotly
def plot_comparison(fields, data, random_last=False):
    fig = make_subplots(rows=1, cols=1, subplot_titles=[f'Comparison of {fields}'])
    
    # Add traces for each file
    for field in fields:
        for i, d in enumerate(data):
            field_data = d.get(field, [])
            if len(field_data) > 0 and isinstance(field_data[0], bool):
                field_data = list(map(lambda x: float(x), field_data))
            if i == len(data) - 1 and random_last:
                fig.add_trace(go.Scatter(y=field_data, mode='lines', name=f'Random rewards'))
            else:
                fig.add_trace(go.Scatter(y=field_data, mode='lines', name=f'{filenames[i]} - {field}'))
    # Customize layout
    fig.update_layout(
        title=f'Comparison of {field}',
        xaxis_title='Step',
        yaxis_title=field,
        showlegend=True,
        hovermode="x"
    )
    
    # Show the interactive plot
    fig.show()
    return fig

# Plot losses
loss_fig = plot_comparison(['loss'], data)


# random = load_json('../random_rewards.json')
# data.append(random)
# Plot avg_rewards
reward_fig = plot_comparison(['reward'], data)
# Out:
# ../vision_0.json
# ../vision_1.json
# ../vision_2.json
# ../vision_3.json
# ../vision_4.json
# ../vision_5.json
# ../vision_6.json
# ../vision_7.json
# ../vision_8.json
# ../vision_9.json
# ../vision_10.json
# ../vision_11.json
# ../vision_12.json
# ../vision_13.json
# ../vision_14.json
# ../vision_15.json
# ../vision_16.json
# ../vision_17.json
# ../vision_18.json
# ../vision_19.json
# ../vision_20.json
# ../vision_21.json
# ../vision_22.json
# ../vision_23.json
# ../vision_24.json
# ../vision_25.json
# ../vision_26.json
# ../vision_27.json
# ../vision_28.json
# ../vision_29.json
# ../vision_30.json
# ../vision_31.json

# %%
# Initialize a list to hold indices of traces to delete
delete_indices = []

# Step 1: Collect indices of traces where last reward < -4
for j, trace in enumerate(reward_fig.data):
        if trace.y[-1] < -4:
            delete_indices.append(j)

# %%
for fig in [loss_fig, reward_fig]:
    fig.data = tuple(trace for i, trace in enumerate(fig.data) if i not in set(delete_indices))

# %%
loss_fig.show()
reward_fig.show()

# %%
import pandas as pd

df = pd.read_json('../vision_params.json')

# %%
df
# Out:
#      alpha     tau architecture  steps_per_update  n  dim  buffer_size  \
# 0   0.0001  0.0001   exp_hidden                10  1  0.9       100000
# 1   0.0010  0.0001   exp_hidden                10  1  0.9       100000
# 2   0.0001  0.0001   exp_hidden                10  1  0.9       100000
# 3   0.0010  0.0001   exp_hidden                10  1  0.9       100000
# 4   0.0001  0.0001   exp_hidden                10  1  0.9       100000
# 5   0.0010  0.0010   exp_hidden                10  1  0.9       100000
# 6   0.0001  0.0010   exp_hidden                10  1  0.9       100000
# 7   0.0010  0.0010   exp_hidden                10  1  0.9       100000
# 8   0.0001  0.0010   exp_hidden                10  1  0.9       100000
# 9   0.0010  0.0010   exp_hidden                10  1  0.9       100000
# 10  0.0001  0.0001   exp_hidden                10  1  0.9       100000
# 11  0.0010  0.0001   exp_hidden                10  1  0.9       100000
# ...

# %% [markdown]
# # Full vision update_step >= 10

# %%
import json
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Function to load JSON file
def load_json(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

# Load JSON files
count = 0
files = []
data = []
filenames = []
while True:
    file = '../vision' + str(count) + '_1.json'
    try:
        data.append(load_json(file_path=file))
        filenames.append(file)
        print(file)
    except:
        break
    count += 1
# Out:
# ../vision0_1.json
# ../vision1_1.json
# ../vision2_1.json
# ../vision3_1.json
# ../vision4_1.json
# ../vision5_1.json
# ../vision6_1.json
# ../vision7_1.json
# ../vision8_1.json
# ../vision9_1.json
# ../vision10_1.json
# ../vision11_1.json
# ../vision12_1.json
# ../vision13_1.json
# ../vision14_1.json
# ../vision15_1.json
# ../vision16_1.json
# ../vision17_1.json
# ../vision18_1.json
# ../vision19_1.json
# ../vision20_1.json
# ../vision21_1.json
# ../vision22_1.json
# ../vision23_1.json
# ../vision24_1.json
# ../vision25_1.json
# ../vision26_1.json
# ../vision27_1.json
# ../vision28_1.json
# ../vision29_1.json
# ../vision30_1.json
# ../vision31_1.json

# %%
loss_fig = plot_comparison(['loss'], data)

reward_fig = plot_comparison(['reward'], data)

# %%
df = pd.read_json('../vision_big_update_step_params.json')
df
# Out:
#      alpha     tau architecture  steps_per_update  n  dim  buffer_size  \
# 0   0.0001  0.0001   exp_hidden               100  1  0.9       100000
# 1   0.0010  0.0001   exp_hidden               100  1  0.9       100000
# 2   0.0001  0.0001   exp_hidden               100  1  0.9       100000
# 3   0.0010  0.0001   exp_hidden               100  1  0.9       100000
# 4   0.0001  0.0001   exp_hidden               100  1  0.9       100000
# 5   0.0010  0.0010   exp_hidden               100  1  0.9       100000
# 6   0.0001  0.0010   exp_hidden               100  1  0.9       100000
# 7   0.0010  0.0010   exp_hidden               100  1  0.9       100000
# 8   0.0001  0.0010   exp_hidden               100  1  0.9       100000
# 9   0.0010  0.0010   exp_hidden               100  1  0.9       100000
# 10  0.0001  0.0001   exp_hidden               100  1  0.9       100000
# 11  0.0010  0.0001   exp_hidden               100  1  0.9       100000
# ...

# %% [markdown]
# # Final version (wrong one t_t)

# %%
import json
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Function to load JSON file
def load_json(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

# Load JSON files
count = 1
files = []
data = []
filenames = []
while True:
    file = '../full_vision_long_run_' + str(count) + '.json'
    try:
        data.append(load_json(file_path=file))
        filenames.append(file)
        print(file)
    except:
        break
    count += 1
# Out:
# ../full_vision_long_run_1.json
# ../full_vision_long_run_2.json
# ../full_vision_long_run_3.json
# ../full_vision_long_run_4.json

# %%
res = [{}]

for k in data[0].keys():
    total = []
    for d in data:
        total += d[k]
    res[0][k] = total

# %%
loss_fig = plot_comparison(['loss'], res)

reward_fig = plot_comparison(['reward'], res)

# %%
import json
import plotly.graph_objs as go
from plotly.subplots import make_subplots

count = 1
files = []
data = []
filenames = []
while True:
    file = '../full_vision_long_run_exp_' + str(count) + '.json'
    try:
        data.append(load_json(file_path=file))
        filenames.append(file)
        print(file)
    except:
        break
    count += 1
# Out:
# ../full_vision_long_run_exp_1.json
# ../full_vision_long_run_exp_2.json
# ../full_vision_long_run_exp_3.json
# ../full_vision_long_run_exp_4.json

# %%
res = [{}]

for k in data[0].keys():
    total = []
    for d in data:
        total += d[k]
    res[0][k] = total

# %%
random_path = '../random_baseline.json'
random_rewards = load_json(random_path)

# %%
loss_fig = plot_comparison(['loss'], res)

reward_fig = plot_comparison(['reward'], [res[0], random_rewards], random_last=True)

# %%
import json
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Function to load JSON file
def load_json(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

# Load JSON files
count = 1
files = []
data = []
filenames = []
while True:
    file = '../full_vision_long_run_small_step_' + str(count) + '.json'
    try:
        data.append(load_json(file_path=file))
        filenames.append(file)
        print(file)
    except:
        break
    count += 1
# Out:
# ../one_maze_1.json

# %%
res = [{}]

for k in data[0].keys():
    total = []
    for d in data:
        total += d[k]
    res[0][k] = total

# %%
loss_fig = plot_comparison(['loss'], res)

reward_fig = plot_comparison(['reward'], res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 loss_fig = plot_comparison(['loss'], res)
#       3 reward_fig = plot_comparison(['reward'], res)
#
# NameError: name 'plot_comparison' is not defined

# %%
import json
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Function to load JSON file
def load_json(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

# Load JSON  files
count = 1
files = []
data = []
filenames = []
while True:
    file = '../200_ep_training_' + str(count) + '.json'
    try:
        data.append(load_json(file_path=file))
        filenames.append(file)
        print(file)
    except:
        break
    count += 1
# Out:
# ../200_ep_training_1.json

# %%
res = [{}]

for k in data[0].keys():
    total = []
    for d in data:
        total += d[k]
    res[0][k] = total

# %%
loss_fig = plot_comparison(['loss'], res)
reward_fig = plot_comparison(['reward'], res)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
